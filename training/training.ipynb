# %%
# %pip install scikit-learn==1.2.0
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from datetime import date, datetime

from pydantic import BaseModel

skill_names = [
    "attack",
    "defence",
    "strength",
    "hitpoints",
    "ranged",
    "prayer",
    "magic",
    "cooking",
    "woodcutting",
    "fletching",
    "fishing",
    "firemaking",
    "crafting",
    "smithing",
    "mining",
    "herblore",
    "agility",
    "thieving",
    "slayer",
    "farming",
    "runecraft",
    "hunter",
    "construction",
]
activity_names = [
    "league",
    "bounty_hunter_hunter",
    "bounty_hunter_rogue",
    "cs_all",
    "cs_beginner",
    "cs_easy",
    "cs_medium",
    "cs_hard",
    "cs_elite",
    "cs_master",
    "lms_rank",
    "soul_wars_zeal",
    "abyssal_sire",
    "alchemical_hydra",
    "barrows_chests",
    "bryophyta",
    "callisto",
    "cerberus",
    "chambers_of_xeric",
    "chambers_of_xeric_challenge_mode",
    "chaos_elemental",
    "chaos_fanatic",
    "commander_zilyana",
    "corporeal_beast",
    "crazy_archaeologist",
    "dagannoth_prime",
    "dagannoth_rex",
    "dagannoth_supreme",
    "deranged_archaeologist",
    "general_graardor",
    "giant_mole",
    "grotesque_guardians",
    "hespori",
    "kalphite_queen",
    "king_black_dragon",
    "kraken",
    "kreearra",
    "kril_tsutsaroth",
    "mimic",
    "nex",
    "nightmare",
    "phosanis_nightmare",
    "obor",
    "phantom_muspah",
    "sarachnis",
    "scorpia",
    "skotizo",
    "Tempoross",
    "the_gauntlet",
    "the_corrupted_gauntlet",
    "theatre_of_blood",
    "theatre_of_blood_hard",
    "thermonuclear_smoke_devil",
    "tombs_of_amascut",
    "tombs_of_amascut_expert",
    "tzkal_zuk",
    "tztok_jad",
    "venenatis",
    "vetion",
    "vorkath",
    "wintertodt",
    "zalcano",
    "zulrah",
    "rifts_closed",
    "artio",
    "calvarion",
    "duke_sucellus",
    "spindel",
    "the_leviathan",
    "the_whisperer",
    "vardorvis",
]


class SkillView(BaseModel):
    skill_name: str
    skill_value: int


class ActivityView(BaseModel):
    activity_name: str
    activity_value: int


class ScraperDataView(BaseModel):
    created_at: datetime
    record_date: date
    scraper_id: int
    player_id: int
    skills: list[SkillView]
    activities: list[ActivityView]

# %%
labels = [
    "Real_Player",
    "Unknown_bot",
    "PVM_Melee_bot",
    "Smithing_bot",
    "Magic_bot",
    "Zulrah_bot",
    "Fishing_bot",
    "Crafting_bot",
    "Mining_bot",
    "Fletching_bot",
    "Hunter_bot",
    "Agility_bot",
    "Woodcutting_bot",
    "Runecrafting_bot",
    "Zalcano_bot",
    "LMS_bot",
    "Thieving_bot",
    "Herblore_bot",
    "Barrows_bot",
    "Soul_Wars_bot",
    "Cooking_bot",
    "Blast_mine_bot",
    "Wintertodt_bot",
    "Vorkath_bot",
    "PVM_Ranged_bot",
    "PVM_Ranged_Magic_bot",
    "Fishing_Cooking_bot",
    "Gauntlet_bot",
    "temp_real_player",
    "Nex_bot",
    "Clue_Scroll_bot",
]

# %%
import csv

# our api will provide us with: hsDataV3
# as such we should convert our data in the same way


def read_csv(file_path: str) -> list[dict]:
    result = []
    assert file_path.endswith(".csv")

    with open(file_path, newline="") as csvfile:
        reader = csv.reader(csvfile)
        for i, row in enumerate(reader):
            if i % 1000 == 0:
                print(i)
            if i == 0:
                # keys = ['player_name', 'player_created_at', 'possible_ban', 'confirmed_ban', 'confirmed_player', 'label_id', 'label', 'id', 'timestamp', 'ts_date', 'Player_id', 'total', 'attack', 'defence', 'strength', 'hitpoints', 'ranged', 'prayer', 'magic', 'cooking', 'woodcutting', 'fletching', 'fishing', 'firemaking', 'crafting', 'smithing', 'mining', 'herblore', 'agility', 'thieving', 'slayer', 'farming', 'runecraft', 'hunter', 'construction', 'league', 'bounty_hunter_hunter', 'bounty_hunter_rogue', 'cs_all', 'cs_beginner', 'cs_easy', 'cs_medium', 'cs_hard', 'cs_elite', 'cs_master', 'lms_rank', 'soul_wars_zeal', 'abyssal_sire', 'alchemical_hydra', 'barrows_chests', 'bryophyta', 'callisto', 'cerberus', 'chambers_of_xeric', 'chambers_of_xeric_challenge_mode', 'chaos_elemental', 'chaos_fanatic', 'commander_zilyana', 'corporeal_beast', 'crazy_archaeologist', 'dagannoth_prime', 'dagannoth_rex', 'dagannoth_supreme', 'deranged_archaeologist', 'general_graardor', 'giant_mole', 'grotesque_guardians', 'hespori', 'kalphite_queen', 'king_black_dragon', 'kraken', 'kreearra', 'kril_tsutsaroth', 'mimic', 'nex', 'nightmare', 'phosanis_nightmare', 'obor', 'phantom_muspah', 'sarachnis', 'scorpia', 'skotizo', 'Tempoross', 'the_gauntlet', 'the_corrupted_gauntlet', 'theatre_of_blood', 'theatre_of_blood_hard', 'thermonuclear_smoke_devil', 'tombs_of_amascut', 'tombs_of_amascut_expert', 'tzkal_zuk', 'tztok_jad', 'venenatis', 'vetion', 'vorkath', 'wintertodt', 'zalcano', 'zulrah', 'rifts_closed', 'artio', 'calvarion', 'duke_sucellus', 'spindel', 'the_leviathan', 'the_whisperer', 'vardorvis']
                keys = row
                continue

            dict_row = {k: 0 if v == "NULL" else v for k, v in zip(keys, row)}

            if dict_row.get("label") not in labels:
                continue

            result.append(
                {
                    "scraper_data": ScraperDataView(
                        created_at=dict_row.get("timestamp"),
                        scraper_id=dict_row.get("id"),
                        player_id=dict_row.get("Player_id"),
                        record_date=dict_row.get("ts_date"),
                        skills=[
                            SkillView(skill_name=s, skill_value=dict_row.get(s, 0))
                            for s in skill_names
                        ],
                        activities=[
                            ActivityView(
                                activity_name=a, activity_value=dict_row.get(a, 0)
                            )
                            for a in activity_names
                        ],
                    ),
                    "label": {
                        "label_id": dict_row.get("label_id"),
                        "label": dict_row.get("label"),
                    },
                }
            )

    return result


data = read_csv("./data/2024-04-04_bd_hs_data.csv")
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000
# 100000
# 101000
# 102000
# 103000
# 104000
# 105000
# 106000
# 107000
# 108000
# 109000
# 110000
# 111000
# 112000
# 113000
# 114000
# 115000
# 116000
# 117000
# 118000
# 119000
# 120000
# 121000
# 122000
# ...

# %%
data[:2]
# Out:
# [{'scraper_data': ScraperDataView(created_at=datetime.datetime(2024, 3, 24, 1, 16, 41), record_date=datetime.date(2024, 3, 24), scraper_id=59568395, player_id=1, skills=[SkillView(skill_name='attack', skill_value=5544444), SkillView(skill_name='defence', skill_value=3779376), SkillView(skill_name='strength', skill_value=5948102), SkillView(skill_name='hitpoints', skill_value=5576374), SkillView(skill_name='ranged', skill_value=2415724), SkillView(skill_name='prayer', skill_value=772783), SkillView(skill_name='magic', skill_value=3699313), SkillView(skill_name='cooking', skill_value=13104896), SkillView(skill_name='woodcutting', skill_value=953744), SkillView(skill_name='fletching', skill_value=6627844), SkillView(skill_name='fishing', skill_value=2422193), SkillView(skill_name='firemaking', skill_value=986930), SkillView(skill_name='crafting', skill_value=1255289), SkillView(skill_name='smithing', skill_value=308228), SkillView(skill_name='mining', skill_value=899001), SkillView(skil
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Extract features and labels from the list of dictionaries
labels = []
skills = []
activities = []

for row in data:
    _data: ScraperDataView = row.get("scraper_data")
    _label = row.get("label").get("label")
    labels.append(_label)

    _skills = {d.skill_name: d.skill_value for d in _data.skills} | {
        "player_id": _data.player_id
    }
    skills.append(_skills)

    _activities = {d.activity_name: d.activity_value for d in _data.activities} | {
        "player_id": _data.player_id
    }
    activities.append(_activities)


print(skills[:2])
print(activities[:2])
print(labels[:2])
# Out:
# [{'attack': 5544444, 'defence': 3779376, 'strength': 5948102, 'hitpoints': 5576374, 'ranged': 2415724, 'prayer': 772783, 'magic': 3699313, 'cooking': 13104896, 'woodcutting': 953744, 'fletching': 6627844, 'fishing': 2422193, 'firemaking': 986930, 'crafting': 1255289, 'smithing': 308228, 'mining': 899001, 'herblore': 109209, 'agility': 861190, 'thieving': 758325, 'slayer': 938294, 'farming': 526439, 'runecraft': 9699, 'hunter': 1197973, 'construction': 117282, 'player_id': 1}, {'attack': 14286978, 'defence': 13294786, 'strength': 15353800, 'hitpoints': 26943191, 'ranged': 20646630, 'prayer': 13138766, 'magic': 16277334, 'cooking': 13057071, 'woodcutting': 13104814, 'fletching': 13192150, 'fishing': 13097576, 'firemaking': 15020972, 'crafting': 13127797, 'smithing': 8067444, 'mining': 3418888, 'herblore': 13143560, 'agility': 2301642, 'thieving': 1567543, 'slayer': 4115938, 'farming': 13416214, 'runecraft': 1235418, 'hunter': 1070150, 'construction': 10700946, 'player_id': 8}]
# ...

# %%
import pandas as pd

df_skills = pd.DataFrame(skills)
df_activities = pd.DataFrame(activities)

# %%
df_skills.head()
# Out:
#      attack   defence  strength  hitpoints    ranged    prayer     magic  \
# 0   5544444   3779376   5948102    5576374   2415724    772783   3699313
# 1  14286978  13294786  15353800   26943191  20646630  13138766  16277334
# 2   1212558     65307   3659401    4302321   4437327    153812  11058613
# 3  17496981  15615659  22795942   35289286  33818840  13628831  17502915
# 4  25789847  19279215  57396170   51308981  45806374  13037612  20373613
#
#     cooking  woodcutting  fletching  ...    mining  herblore   agility  \
# 0  13104896       953744    6627844  ...    899001    109209    861190
# 1  13057071     13104814   13192150  ...   3418888  13143560   2301642
# 2    288222       756718     273767  ...   4227025     88621     72822
# 3  16004970     17356549   13601312  ...  15261979  13084882  13393868
# 4  13144778     13051121   13940518  ...   3350277   6007298   3598385
#
#    thieving    slayer   farming  runecraft    hunter  construction  player_id
# ...

# %%
import pandas as pd

X = pd.DataFrame(features)
X.head()

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X, labels, test_size=0.2, random_state=42, stratify=labels
)

# %%
# Choose a classifier (e.g., DecisionTreeClassifier)
clf = DecisionTreeClassifier()

# Train the classifier
clf.fit(X_train, y_train)

# Make predictions on the test set
y_pred = clf.predict(X_test)

# Evaluate the classifier
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# %%
myLabels = ["Real_Player"]
for i, l in enumerate(labels):
    if l not in myLabels:
        print(i, l)
        myLabels.append(l)

# %%
batch = 10
start = 186289
end = start + batch

_data = [list(f.values()) for f in features[start:end]]
predictions = clf.predict_proba(_data)
predictions = predictions.tolist()

for p, l in zip(predictions, labels[start:end]):
    for k, v in zip(clf.classes_, p):
        if v > 0:
            print(l, k, v)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
